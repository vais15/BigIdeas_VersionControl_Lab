# %%
# creates a username for the user using their name and id
name = input("Type in your name")
id = input("Type in your id")
print ("Here is your id:", name + id)
# Out:
# Type in your name raimasaha
# Type in your id 2397458945]
# Here is your id: raimasaha2397458945]
